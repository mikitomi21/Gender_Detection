# %%
from scripts.download_data import DataDownloader

# %%
DataDownloader.download_data()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/frabbisw/facial-age
# 2131
# ✅ Dataset 'frabbisw/facial-age' downloaded to directory: C:\Users\kubas\repo\Gender_Detection\data\raw\babies
# 🙈 Dataset 'ashishjangra27/gender-recognition-200k-images-celeba' is already downloaded.
# 🙈 Dataset 'felicepollano/watermarked-not-watermarked-images' is already downloaded.
