# %%
from scripts.download_data import DataDownloader

# %%
DataDownloader.download_data()
# Out:
# 🙈 Dataset 'frabbisw/facial-age' is already downloaded.
# Dataset URL: https://www.kaggle.com/datasets/ashishjangra27/gender-recognition-200k-images-celeba
# ✅ Dataset 'ashishjangra27/gender-recognition-200k-images-celeba' downloaded to directory: C:\Users\kubas\repo\Gender_Detection\data\processed
# 🙈 Dataset 'felicepollano/watermarked-not-watermarked-images' is already downloaded.
